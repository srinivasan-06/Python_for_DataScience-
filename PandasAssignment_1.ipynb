# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivasan-06/Python_for_DataScience-/blob/main/PandasAssignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Start off by importing the customer_churn.csv file in the jupyter notebook
# and store that in churn DataFrame.

# %%
import pandas as pd
data = pd.read_csv('customer_churn-1.csv')
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
#  From the churn DataFrame, select only 3rd, 7th, 9th, and 20th columns
# and all the rows and store that in a new DataFrame named newCols

# %%
newCols = data.iloc[:,[2,6,8,19]]
newCols
# Out:
#       SeniorCitizen PhoneService InternetService TotalCharges
# 0                 0           No             DSL        29.85
# 1                 0          Yes             DSL       1889.5
# 2                 0          Yes             DSL       108.15
# 3                 0           No             DSL      1840.75
# 4                 0          Yes     Fiber optic       151.65
# ...             ...          ...             ...          ...
# 7038              0          Yes             DSL       1990.5
# 7039              0          Yes     Fiber optic       7362.9
# 7040              0           No             DSL       346.45
# 7041              1          Yes     Fiber optic        306.6
# 7042              0          Yes     Fiber optic       6844.5
#
# [7043 rows x 4 columns]

# %% [markdown]
# From the original DataFrame, select only the rows from the 200th index till
# the 1000th index(inclusive) column

# %%
df = data.iloc[200:1001]
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 200   9323-HGFWY  Female              0     Yes         No      27
# 201   8544-GOQSH  Female              0      No         No      14
# 202   3363-DTIVD    Male              0     Yes        Yes      71
# 203   7018-WBJNK    Male              0      No        Yes      13
# 204   9142-KZXOP    Male              0      No         No      44
# ...          ...     ...            ...     ...        ...     ...
# 996   6641-XRPSU  Female              0      No         No      34
# 997   1374-DMZUI  Female              1      No         No       4
# 998   2545-LXYVJ    Male              0     Yes         No      72
# 999   3234-VKACU    Male              0      No         No       2
# 1000  8357-EQXFO  Female              0      No         No       7
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 200           Yes            No     Fiber optic                  Yes  ...
# ...

# %% [markdown]
# Now select the rows from 20th index till 200th index(exclusive),and
# columns from 2nd index till 15th index value.

# %%
index = data.iloc[20:200,2:15]
index
# Out:
#      SeniorCitizen Partner Dependents  tenure PhoneService     MultipleLines  \
# 20               1      No         No       1           No  No phone service
# 21               0     Yes         No      12          Yes                No
# 22               0      No         No       1          Yes                No
# 23               0     Yes         No      58          Yes               Yes
# 24               0     Yes        Yes      49          Yes                No
# ..             ...     ...        ...     ...          ...               ...
# 195              0     Yes         No      20          Yes                No
# 196              0     Yes        Yes      24          Yes               Yes
# 197              0      No         No      59          Yes               Yes
# 198              0     Yes        Yes      72          Yes               Yes
# 199              0      No        Yes       1          Yes                No
#
# ...

# %% [markdown]
#  Display the top 100 records from the original DataFrame

# %%
top_100 = data.head(100)
top_100
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 95  8637-XJIVR  Female              0      No         No      12          Yes
# 96  9803-FTJCG    Male              0     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male              0      No         No       5          Yes
# 98  3212-KXOCR    Male              0      No         No      52          Yes
# 99  4598-XLKNJ  Female              1     Yes         No      25          Yes
#
# ...

# %% [markdown]
#  Display the last 10 records from the DataFrame.

# %%
Bottom = data.tail(10)
Bottom
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %% [markdown]
# Display the last record from the DataFrame

# %%
last = data.tail(1)
last
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 7042          Yes            No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 7042              Yes         Yes         Yes             Yes  Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7042    No
#
# [1 rows x 21 columns]

# %% [markdown]
# Now from the churn DataFrame, try to sort the data by the tenure column
# according to the descending order

# %%
tenure = data.sort_values(by = 'tenure', ascending = False)
tenure
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3177  1814-WFGVS    Male              0     Yes        Yes      72
# 3131  8336-TAVKX  Female              1     Yes         No      72
# 3107  5038-ETMLM  Female              0     Yes         No      72
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# 3111  8809-RIHDD    Male              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3177           No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
#  Fetch all the records that are satisfying the following condition:
# a. Tenure>50 and the gender as ‘Female’
# b. Gender as ‘Male’ and SeniorCitizen as 0
# c. TechSupport as ‘Yes’ and Churn as ‘No’
# d. Contract type as ‘Month-to-month’ and Churn as ‘Yes’

# %%
greater = data[(data['tenure'] > 50) & (data['gender'] == 'Female')]
greater
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 23    3638-WEABW  Female              0     Yes         No      58
# 30    3841-NFECX  Female              1     Yes         No      71
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 15            Yes           Yes     Fiber optic                  Yes  ...
# ...

# %%
male = data[(data['gender']== 'Male') & (data['SeniorCitizen'] == 0)]
male
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 2     3668-QPYBK   Male              0      No         No       2
# 3     7795-CFOCW   Male              0      No         No      45
# 6     1452-KIOVK   Male              0      No        Yes      22
# 9     6388-TABGU   Male              0      No        Yes      62
# ...          ...    ...            ...     ...        ...     ...
# 7027  0550-DCXLH   Male              0      No         No      13
# 7033  9767-FFLEM   Male              0      No         No      38
# 7035  8456-QDAVC   Male              0      No         No      19
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
tech = data[(data['TechSupport'] == 'yes') & (data['Churn'] == 'no')]
tech
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
month = data[(data['Contract'] == 'Month-to-month') & (data['Churn'] == 'yes')]
month
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Use a for loop to calculate the number of customers that are getting the
# tech support and are male senior citizens.
