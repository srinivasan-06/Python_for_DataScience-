# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivasan-06/Python_for_DataScience-/blob/main/NumpyAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Create a list named ‘myList’ that has the following elements: 10, 20, 30,
# ‘apple’, True, 8.10:
# a. Now in the ‘myList’, append these values: 30, 40
# b. After that, reverse the elements of the ‘myList’ and store that in
# ‘reversedList’**

# %%
mylist = [10,20,30,'apple','true',8.10]
mylist.append(30)
mylist.append(40)
print(mylist)
# Out:
# [10, 20, 30, 'apple', 'true', 8.1, 30, 40]

# %%
revlist = mylist[::-1]
print(revlist)
# Out:
# [40, 30, 8.1, 'true', 'apple', 30, 20, 10]

# %% [markdown]
# **Create a dictionary with key values as 1, 2, 3 and the values as ‘data’,
# ‘information’ and ‘text’:
# a. After that, eliminate the ‘text’ value from the dictionary
# b. Add ‘features’ in the dictionary
# c. Fetch the ‘data’ element from the dictionary and display it in the output**

# %%
dictionary = {1:'data', 2:'information', 3:'text'}
dictionary.pop(3)
print(dictionary)
# Out:
# {1: 'data', 2: 'information'}

# %%
dictionary.update({3:'feature'})
print(dictionary)
# Out:
# {1: 'data', 2: 'information', 3: 'feature'}

# %%
print(dictionary[1])
# Out:
# data

# %% [markdown]
# **Create a tuple and add these elements 1, 2, 3, apple, mango in my_tuple.**

# %%
my_tuple = (1,2,3,'apple','mango')
print(my_tuple)
# Out:
# (1, 2, 3, 'apple', 'mango')

# %% [markdown]
# **Create another tuple named numeric_tuple consisting of only integer
# values 10, 20, 30, 40, 50:
# a. Find the minimum value from the numeric_tuple
# b. Concatenate my_tuple with numeric_tuple and store the result in r1
# c. Duplicate the tuple named my_tuple 2 times and store that in ‘newdupli’**

# %%
numeric_tuple = (10,20,30,40,50)
print(min(numeric_tuple))
# Out:
# 10

# %%
r1 = my_tuple + numeric_tuple
print(r1)
# Out:
# (1, 2, 3, 'apple', 'mango', 10, 20, 30, 40, 50)

# %%
newdupli = my_tuple * 2
print(newdupli)
# Out:
# (1, 2, 3, 'apple', 'mango', 1, 2, 3, 'apple', 'mango')

# %% [markdown]
# **Create 2 sets with the names set1 and set2, where set1 contains
# {1,2,3,4,5} and set2 contains {2,3,7,6,1}
# Perform the below operation:
# a. set1 union set2
# b. set1 intersection set2
# c. set1 difference set2**

# %%
set1 = {1,2,3,4,5}
set2 = {2,3,7,6,1}
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
print(set1.intersection(set2))
# Out:
# {1, 2, 3}

# %%
print(set1.difference(set2))
# Out:
# {4, 5}
