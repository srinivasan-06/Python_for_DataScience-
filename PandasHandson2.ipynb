# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivasan-06/Python_for_DataScience-/blob/main/PandasHandson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Import pandas by typing the following code in the notebook and run it by
# pressing shift + enter

# %%
import pandas as pd

# %% [markdown]
#  Type the following code to create a pandas DataFrame using an array

# %%
df = pd.DataFrame([1,2,3,4,5])
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# Type the following code to create a pandas DataFrame using an 2d array

# %%
data = [["srini", 25], ["sri", 24], ["mith", 24]]
df = pd.DataFrame(data,columns=["name", "age"])
df
# Out:
#     name  age
# 0  srini   25
# 1    sri   24
# 2   mith   24

# %% [markdown]
# Type the following code to create a pandas DataFrame using a dictionary

# %%
data = {'Name': ['srini', 'sri', 'mith'], 'Age' :[24 , 35, 24]}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age
# 0  srini   24
# 1    sri   35
# 2   mith   24
