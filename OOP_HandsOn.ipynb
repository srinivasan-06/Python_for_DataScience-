# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivasan-06/Python_for_DataScience-/blob/main/OOP_HandsOn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Design a class BankAccount that has the following attributes:
#
# Account_number
#
# Account_holder
#
# balance
#
# Add Methods:
#
# Deposite(amount)
#
# Withdraw(amount)
#
# Display_balance()

# %%
class BankAccount:
  def __init__(self,account_number,account_holder,balance=0):
        self.account_number = account_number
        self.account_holder = account_holder
        self.balance = balance

  def deposit(self,amount):
    self.balance+=amount

  def withdraw(self,amount):
    if amount<=self.balance:
      self.balance-=amount
    else:
      print('insufficient balance')

  def display_balance(self):
    print(f'account :{self.account_holder} , balance: {self.balance}')



obj1=BankAccount('123','pooja')
obj1.display_balance()

obj1.deposit(100000)
obj1.display_balance()

obj1.withdraw(27000)
obj1.display_balance()

obj1.withdraw(270000)
obj1.display_balance()
# Out:
# account :pooja , balance: 0
# account :pooja , balance: 100000
# account :pooja , balance: 73000
# insufficient balance
# account :pooja , balance: 73000

# %% [markdown]
# # Q2. You're creating a library management system. LibraryMember has name and member Id. A PremiumMember can borrow up to 5 books. Track how many books they borrowed and stop them if they reach the limit.
